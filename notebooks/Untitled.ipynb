# %%
from unsys import *
import numpy as np
import sympy.physics.quantum as spq

# %%
qs = QuditSystem(2,2)
qs.postSelect(1,spq.Ket(0))
qs.draw()
# Out:
# id#1

# %%
qs = QuditSystem(2,3,symbolic=True)
#qs.draw()
