# %%
from unsys import *
import numpy as np

# %%
qs = QuditSystem(2,2)
qs.draw()

# %%
qs = QuditSystem(2,3,symbolic=True)
qs.draw()

# %%
qs = QuditSystem(2,3,symbolic=True)
qs.interactive()
HypernetxWidget(qs.hypergraph)
# Out:
# HypernetxWidget(component='HypernetxWidget', props={'nodes': [{'uid': 'id#10'}, {'uid': 'id#9'}], 'edges': [{'…
