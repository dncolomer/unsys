# %%
from unsys import *
import numpy as np
import sympy.physics.quantum as spq

# %%
expr = spq.Ket(0) + spq.Ket('a')
expr2 = spq.Ket(1) + spq.Ket('a') 
s1 = expr.free_symbols
s2 = expr2.free_symbols

print(len(s1.intersection(s2)))
# Out:
# 1

# %%
qs = QuditSystem(2,2)

qs.postSelect(1,spq.Ket(1))
qs.draw()

# %%
qs = QuditSystem(2,2)
qs.draw()

print(qs.getStatevectorIndices())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19524/2830632663.py in <module>
#       2 qs.draw()
#       3
# ----> 4 print(qs.getStatevectorIndices())
#
# c:\users\dcolomer\documents\workspace\unsys\unsys\__init__.py in getStatevectorIndices(self)
#      82                 joint_combos = []
#      83                 for node_combo in combos:
# ---> 84                     joint_combos.append(node_combo[0] + (node_combo[1],))
#      85
#      86                 all_combos.append(joint_combos)
#
# IndexError: list index out of range

# %%
import itertools as itertools
list1 = [1,2,3]
list2 = [4,5]

flat = []
all_combinations = [list(zip(each_permutation, list2)) for each_permutation in itertools.permutations(list1, len(list2))]
print(all_combinations)
for e in all_combinations:
    for ts in e:
        flat.append(ts)

print(set(flat))
# Out:
# [[(1, 4), (2, 5)], [(1, 4), (3, 5)], [(2, 4), (1, 5)], [(2, 4), (3, 5)], [(3, 4), (1, 5)], [(3, 4), (2, 5)]]
# {(2, 4), (3, 4), (1, 5), (1, 4), (2, 5), (3, 5)}
